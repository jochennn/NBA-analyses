# %% [markdown]
# # NBA ROLE PLAYER KNN ANALYSIS

# %% [markdown]
# ### IMPORTING DATA & LIBRARIES

# %%
# nba data
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import teams
from nba_api.stats.static import players

# packages
import pandas as pd
import altair as alt
import matplotlib.pyplot as plt
import seaborn as sn

# %%
# load nba team information
nba_teams = teams.get_teams()

# %%
# load nba player info
nba_players = players.get_players()

# %%
# load in chunk data from google sheets 9from URL)
nba_data = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQ-1fqyvskEHodIPX8O-4_QvUHmXUXCAvNETbYZs8e0ZRO_trGzV64tDjskf_oe_t83JjpzOS_D5kfZ/pub?gid=1833496207&single=true&output=csv")
nba_data
# Out:
#       Unnamed: 0             name  player_height  player_weight  \
# 0              0   Jamal Crawford         195.58      90.718400
# 1              1   Jamal Mashburn         203.20     109.315672
# 2              2       Ira Bowman         195.58      88.450440
# 3              3     Jamel Thomas         198.12      99.336648
# 4              4  Dikembe Mutombo         218.44     120.201880
# ...          ...              ...            ...            ...
# 9751        9751  Markieff Morris         205.74     111.130040
# 9752        9752   Markelle Fultz         193.04      94.800728
# 9753        9753     Marcus Smart         193.04      99.790240
# 9754        9754   Marcus Garrett         195.58      92.986360
# 9755        9755     Micah Potter         208.28     112.490816
#
#              college country draft_year draft_round draft_number   pts  ...  \
# 0           Michigan     USA       2000           1            8   4.6  ...
# ...

# %% [markdown]
# ### EDA

# %%
## Removing 'Unnamed: 0' column along with duplicate columns
nba_data = nba_data.drop(columns = ["Unnamed: 0", "pts", "reb", "ast"])

# %%
## keep NAs where NA is placeholder for a zero - example: some NAs are because a center didn't take 3 pointers
pd.DataFrame(data.isna().sum()).sort_values(by = 0,ascending = False).head(20)

# Removing all other rows with NA values
data = data.dropna()
data.isna().values.any()
# Out:
#                                0
# % of FG Ast'd 3P            2687
# Corner 3s 3P%               2586
# FG% by Distance 3P          1488
# Corner 3s %3PA              1488
# FG% by Distance 16-3P        906
# FG% by Distance 10-16        868
# FG% by Distance 3-10         651
# FG% by Distance 0-3          493
# % of FG Ast'd 2P             446
# FG% by Distance 2P           327
# % of FGA by Distance 3-10    293
# Dunks %FGA                   293
# % of FGA by Distance 2P      293
# Dist.                        293
# FG%                          293
# % of FGA by Distance 0-3     293
# % of FGA by Distance 3P      293
# % of FGA by Distance 16-3P   293
# % of FGA by Distance 10-16   293
# # of Heaves                  253
